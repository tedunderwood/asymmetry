# %% [markdown]
# # Merge for second supplement
#
# So, I've got metadata tables listing books that will
# supplement the central, random sample in a variety of ways.
#
# I need to merge those tables into a single master list that
# has all the information we need for further analysis.
#
# In theory this could be done with joins, but it would end
# up being opaque both to me and to readers. Better in this
# case, I think, to spell everything out with procedural
# explicitness.

# %%
import pandas as pd
from difflib import SequenceMatcher

# %%
work = pd.read_csv('../../noveltmmeta/workmeta.tsv', sep = '\t', low_memory = False, index_col = 'docid')
work.columns.tolist()
# Out:
# ['oldauthor',
#  'author',
#  'authordate',
#  'inferreddate',
#  'latestcomp',
#  'datetype',
#  'startdate',
#  'enddate',
#  'imprint',
#  'imprintdate',
#  'contents',
#  'genres',
#  'subjects',
#  'geographics',
#  'locnum',
#  'oclc',
#  'place',
#  'recordid',
#  'instances',
#  'allcopiesofwork',
#  'copiesin25yrs',
#  'enumcron',
#  'volnum',
#  'title',
#  'parttitle',
#  'earlyedition',
#  'shorttitle']

# %%
best = pd.read_csv('bestsellers/deduplicated_bestsellers.tsv', sep = '\t')

# %%
matched = pd.read_csv('canon/fuzzy_matched_canon.tsv', sep = '\t')

# %%
firstsample = pd.read_csv('../supplement1/lastnamesupp1meta.tsv', sep = '\t')

# %%
master = pd.read_csv('../../noveltmmeta/masterficmetadata.tsv', sep = '\t', low_memory = False, index_col = 'docid')

# %% [markdown]
# ### Desired columns
#
#     docid
#     author
#     title -- will be equiv to workmeta "shorttitle"
#     inferreddate (workmeta)
#     latestcomp (workmeta -- this will be used for processing, and must be filled out)
#     firstpub (a step beyond latestcomp to true firstpub; we won't have for all rows)
#     allcopiesofwork
#     copiesin25yrs
#     gender
#     nationality
#     earlyedition
#     lastname
#     imprint
#
# In addition to general metadata, there will be several columns that define reasons for selection. Since the same volume can be selected for more than one reason, it's possible to have "True" in more than one of these columns.
#
#     heath
#     norton
#     nortonshort
#     bestseller
#     mostdiscussed
#     reviewed
#     contrast4reviewed
#     preregistered

# %%
newdata = dict()

# %%
for idx, row in firstsample.iterrows():
    r = dict()
    r['docid'] = row['docid']
    r['author'] = row['author']
    r['title'] = row['title']
    r['inferreddate'] = row['actualdate']
    r['latestcomp'] = row['earliestdate']
    r['firstpub'] = row['earliestdate']
    r['allcopiesofwork'] = float('nan')
    r['copiesin25yrs'] = float('nan')
    r['gender'] = row['gender']
    r['nationality'] = row['nationality']
    r['earlyedition'] = float('nan')
    r['lastname'] = row['lastname']
    r['imprint'] = float('nan')
    
    if row['tags'] == 'vulgar':
        r['contrast4reviewed'] = True
        r['reviewed'] = False
        r['preregistered'] = False
    elif row['tags'] == 'elite':
        r['contrast4reviewed'] = False
        r['reviewed'] = True
        r['preregistered'] = False
    elif row['tags'] == 'special':
        r['preregistered'] = True
        r['reviewed'] = False
        r['contrast4reviewed'] = False
    else:
        continue
    
    for col in ['mostdiscussed', 'bestseller', 'nortonshort', 'norton', 'heath']:
        r[col] = False
        # for now! this could be revised later
    
    newdata[r['docid']] = r

# %%
for idx, row in best.iterrows():
    docid = row['docid']
    if docid in newdata:
        r = newdata[docid]
        r['imprint'] = row['imprint']
        
        if pd.isnull(row['firstpub']):
            firstpub = float('nan')
        else:
            firstpub = int(row['firstpub'])
            
        if firstpub < int(r['latestcomp']):
            r['latestcomp'] = row['firstpub']
        
    else:
        r = dict()
        r['docid'] = row['docid']
        r['author'] = row['author']
        r['title'] = row['title']
        r['inferreddate'] = row['inferreddate']
        r['latestcomp'] = row['firstpub']
        r['firstpub'] = row['firstpub']
        r['allcopiesofwork'] = float('nan')
        r['copiesin25yrs'] = float('nan')
        r['gender'] = row['gender']
        r['nationality'] = row['nationality']
        r['earlyedition'] = float('nan')
        r['lastname'] = float('nan')
        r['imprint'] = float('nan')
        for col in ['mostdiscussed', 'nortonshort', 'norton', 'heath', 'preregistered', 
                    'reviewed', 'contrast4reviewed', 'bestseller']:
            r[col] = False
    
    r['bestseller'] = True
    newdata[docid] = r

# %%
obligatecols = ['docid', 'author', 'title', 'inferreddate', 'latestcomp', 'firstpub', 
                'allcopiesofwork', 'copiesin25yrs', 'gender', 'nationality', 'earlyedition',
               'lastname', 'imprint']
tfcols = ['norton', 'heath', 'nortonshort', 'mostdiscussed', 'preregistered', 'reviewed', 'contrast4reviewed', 'bestseller']

# %%
for idx, row in matched.iterrows():
    r = dict()
    r['docid'] = row['docid']
    r['author'] = row['author']
    r['title'] = row['shorttitle']
    r['inferreddate'] = row['inferreddate']
    r['latestcomp'] = row['latestcomp']
    r['firstpub'] = float('nan')
    r['allcopiesofwork'] = row['allcopiesofwork']
    r['copiesin25yrs'] = row['copiesin25yrs']
    r['gender'] = float('nan')
    r['nationality'] = float('nan')
    r['earlyedition'] = row['earlyedition']
    r['lastname'] = float('nan')
    r['imprint'] = row['imprint']
    r['norton'] = row['norton']
    r['heath'] = row['heath']
    r['nortonshort'] = row['nortonshort']
    r['mostdiscussed'] = False
    r['preregistered'] = False
    r['reviewed'] = False
    r['contrast4reviewed'] = False
    r['bestseller'] = False

    if r['docid'] in newdata:
        toupdate = newdata[r['docid']]
        
        for col in obligatecols:
            if pd.isnull(toupdate[col]) and not pd.isnull(r[col]):
                toupdate[col] = r[col]
                print(toupdate[col])
        
        for col in tfcols:
            if toupdate[col] == False and r[col] == True:
                toupdate[col] = True
        
        newdata[r['docid']] = toupdate
    
    else:
        newdata[r['docid']] = r
# Out:
# 18
# 2
# True
# 25
# 4
# True
# Boston;Ticknor and Field;1866.
# 1885
# 31
# 4
# True
# New York;C. L. Webster and company;1885.
# 1906
# 8
# 2
# True
# New York;Doubleday, Page & Company;1906.
# 1912
# 2
# 2
# True
# Boston;New York;Houghton Mifflin Co.;1912.
# 1917
# 7
# 3
# True
# New York;Grosset & Dunlap;c1917.
# 1939
# 11
# 6
# True
# New York|The Viking press|c1939
# 1952
# 5
# 2
# True
# New York|Random House|1952

# %%
len(newdata)
# Out:
# 2121

# %%
correx = 0
caught = 0

for docid, row in newdata.items():
    if pd.isnull(row['lastname']):
        if pd.isnull(row['author']):
            row['lastname'] == 'anon'
        else:
            names = row['author'].split()
            lastname = names[0].strip('()[],.')
            row['lastname'] = lastname
            
    if docid in work.index:
        refrow = work.loc[docid, : ]
        for col in obligatecols:
            if col in {'firstpub', 'gender', 'nationality', 'lastname'}:
                continue
                
            if pd.isnull(row[col]) and not pd.isnull(refrow[col]):
                row[col] = refrow[col]
                correx += 1
    else:
        if docid in master.index and pd.isnull(row['imprint']):
            row['imprint'] = master.loc[docid, 'imprint']
            caught += 1
            
print(correx)
print(caught)
# Out:
# 6307
# 455

# %%
aslist = []
for key, value in newdata.items():
    aslist.append(value)
newdf = pd.DataFrame(aslist)
newdf.head()
# Out:
#    allcopiesofwork                  author bestseller contrast4reviewed  \
# 0              3.0         Hough, Emerson,       True             False
# 1             27.0  Cooper, James Fenimore      False             False
# 2              1.0              anonymous6      False             False
# 3              NaN          Scott, Walter,       True             False
# 4              NaN      Williams, Ben Ames      False             False
#
#    copiesin25yrs               docid earlyedition  firstpub gender  heath  \
# 0            3.0  mdp.39015063923869         True    1909.0    NaN  False
# 1            3.0        uc1.b3321331         True       NaN    NaN  False
# 2            1.0  uc1.32106006691585         True    1902.0      f  False
# 3            NaN  nyp.33433075743603          NaN    1818.0      m  False
# 4            NaN  mdp.39015030719481          NaN    1944.0      m  False
#
#                         ...                       inferreddate    lastname  \
# 0                       ...                             1909.0       Hough
# 1                       ...                             1856.0      Cooper
# 2                       ...                             1902.0  anonymous6
# 3                       ...                             1824.0       Scott
# 4                       ...                             1944.0    Williams
#
#   latestcomp  mostdiscussed nationality norton nortonshort preregistered  \
# 0     1909.0          False         NaN  False       False         False
# 1     1851.0          False         NaN   True       False         False
# 2     1902.0          False          ir  False       False         False
# 3     1818.0          False          uk  False       False         False
# 4     1944.0          False          us  False       False         False
#
#   reviewed                                           title
# 0    False                                  54-40 or fight
# 1    False  The last of the Mohicans : a narrative of 1757
# 2     True                         Cuchulain of Muirthemne
# 3    False                                         Rob Roy
# 4     True                             Leave Her to Heaven
#
# [5 rows x 21 columns]

# %%
cols = list(obligatecols)
cols.extend(tfcols)
newdf = newdf[cols]
newdf.to_csv('second_supplement.tsv', sep = '\t', index = False)

# %%
sum(newdf.bestseller)
# Out:
# 849

# %%
sum(newdf.reviewed)
# Out:
# 600

# %%
sum(newdf.heath)
# Out:
# 46

# %% [markdown]
# ### Add most-discussed volumes

# %%
discussed = pd.read_csv('canon/most_discussed.tsv', sep = '\t')

# %%
discussed.head()
# Out:
#   docid            author                  title
# 0   NaN      James, Henry           The American
# 1     X      James, Henry  The Turn of the Screw
# 2   NaN      James, Henry     Portrait of a Lady
# 3   NaN  Melville, Herman              Moby Dick
# 4     X    Morrison, Toni                Beloved

# %%
def blockcode(aname):
    if pd.isnull(aname):
        block = 'xx'
    elif len(aname) < 3:
        block = 'nn'
    else:
        block = aname.lower()[0:2]
    
    return block

work = work.assign(block = work.author.map(blockcode))

byblock = work.groupby('block')
block_dictionary = dict()

for code, df in byblock:
    block_dictionary[code] = df

# %%
def interpret_tag(volnum):
    try:
        volnum = int(volnum)
    except:
        volnum = 1
        print('error in source')
        
    if volnum == 1:
        return 'norton'
    elif volnum == 2:
        return 'nortonshort'
    elif volnum == 3:
        return 'heath'
    else:
        print('This should never happen.')

def fuzzymatch(str1, str2):
    
    m = SequenceMatcher(None, str1, str2)
    match = m.real_quick_ratio()
    if match > 0.7:
        match = m.ratio()
    
    return match

allmatches = []

for idx, row in discussed.iterrows():
    if pd.isnull(row['docid']):
        continue
        
    normname = row['author'].lower()
    
    title = row['title'].lower()
    if len(title) > 28:
        title = title[0:28]
    code = normname[0:2]
    
    possiblematches = []
    
    if code in block_dictionary:
        block = block_dictionary[code]
        for idx2, row2 in block.iterrows():
            auth2match = row2['author'].lower()
            if '(' in auth2match:
                auth2match = auth2match.split('(')[0]
            authsimilarity = fuzzymatch(normname, auth2match)
            if authsimilarity < 0.74: 
                continue
            
            title2match = row2['shorttitle']
            if pd.isnull(title2match):
                title2match = 'x x x'
            else:
                title2match = title2match.lower()
                if len(title2match) > 28:
                    title2match = title2match[0:28]
                
            titlesimilarity = fuzzymatch(title, title2match)
            if titlesimilarity > 0.7:
                possiblematches.append((authsimilarity * titlesimilarity, idx2))

    if len(possiblematches) > 0:
        possiblematches.sort()
        probability, matchidx = possiblematches[-1]
        
        print(normname, ' | ', title, block.loc[matchidx, 'author'], ' == ', block.loc[matchidx, 'shorttitle'])
        allmatches.append(matchidx)
    else:
        print(normname, ' || ', title, "NO MATCH")
# Out:
# james, henry  |  the turn of the screw James, Henry  ==  The turn of the screw : and other stories
# morrison, toni  |  beloved Morrison, Toni  ==  Love
# morrison, toni  |  sula Morrison, Toni  ==  Sula
# james, henry  |  ambassadors James, Henry  ==  The ambassadors
# nabokov, vladimir  ||  ada NO MATCH
# james, henry  |  wings of the dove James, Henry  ==  The wings of the dove
# stowe, harriet beecher  |  dred Stowe, Harriet Beecher  ==  Dred
# james, henry  |  golden bowl James, Henry  ==  The golden bowl
# faulkner, william  |  sanctuary Faulkner, William  ==  Sanctuary
# morrison, toni  |  jazz Morrison, Toni  ==  Jazz
# melville, herman  ||  confidence man NO MATCH
# hurston, zora neale  |  their eyes were watching god Hurston, Zora Neale  ==  Their eyes were watching God; a novel
# hawthorne, nathaniel  |  the house of the seven gable Hawthorne, Nathaniel  ==  The house of the seven gables : and The snow image and other Twice-told tales--
# hawthorne, nathaniel  |  the blithedale romance Hawthorne, Nathaniel  ==  The Blithedale romance
# melville, herman  ||  billy budd NO MATCH
# faulkner, william  |  the sound and the fury Faulkner, William  ==  The sound and the fury
# james, henry  |  the bostonians James, Henry  ==  The Bostonians;
# wright, richard  ||  black boy NO MATCH
# faulkner, william  |  absalom, absalom Faulkner, William  ==  Absalom, absalom!

# %%
allmatches
# Out:
# ['pst.000029895397',
#  'mdp.39015059959802',
#  'mdp.39015043798431',
#  'coo.31924052984741',
#  'uc2.ark+=13960=fk8pc2tq9r',
#  'uc1.b3325140',
#  'uva.x000926858',
#  'inu.30000048939361',
#  'uc1.32106016923267',
#  'uc1.32106007902726',
#  'uva.x030497933',
#  'nyp.33433076087844',
#  'mdp.39015046349141',
#  'uc2.ark+=13960=t5j96177f',
#  'mdp.39015040129580']

# %%
takecols = ['author', 'shorttitle', 'inferreddate', 'latestcomp',
                'allcopiesofwork', 'copiesin25yrs', 'earlyedition', 'imprint']
discussdf = work.loc[allmatches, takecols]
discussdf.head()
# Out:
#                                    author  \
# docid
# pst.000029895397             James, Henry
# mdp.39015059959802         Morrison, Toni
# mdp.39015043798431         Morrison, Toni
# coo.31924052984741           James, Henry
# uc2.ark+=13960=fk8pc2tq9r    James, Henry
#
#                                                           shorttitle  \
# docid
# pst.000029895397           The turn of the screw : and other stories
# mdp.39015059959802                                              Love
# mdp.39015043798431                                              Sula
# coo.31924052984741                                   The ambassadors
# uc2.ark+=13960=fk8pc2tq9r                      The wings of the dove
#
#                            inferreddate  latestcomp  allcopiesofwork  \
# docid
# pst.000029895397                   1969        1916                1
# mdp.39015059959802                 2003        2003                1
# mdp.39015043798431                 1973        1973                4
# coo.31924052984741                 1903        1903               17
# uc2.ark+=13960=fk8pc2tq9r          1902        1902               23
#
#                            copiesin25yrs earlyedition  \
# docid
# pst.000029895397                       1        False
# mdp.39015059959802                     1         True
# mdp.39015043798431                     3         True
# coo.31924052984741                     5         True
# uc2.ark+=13960=fk8pc2tq9r             16         True
#
#                                                                      imprint
# docid
# pst.000029895397                                 Harmondsworth|Penguin|1969.
# mdp.39015059959802         New York|Knopf|Distributed by Random House|c2003.
# mdp.39015043798431                                 New York, NY|Plume|c1973.
# coo.31924052984741               New York and London;Harper & brothers;1903.
# uc2.ark+=13960=fk8pc2tq9r        Westminster;A. Constable and co. ltd.;1902.

# %%
discussdf['gender'] = float('nan')
discussdf['firstpub'] = float('nan')
discussdf['nationality'] = float('nan')

def get_lastname(aname):
    names = aname.split()
    lastname = names[0].strip(',')
    return lastname

discussdf = discussdf.assign(lastname = discussdf.author.map(get_lastname))
discussdf.head()
# Out:
#                                    author  \
# docid
# pst.000029895397             James, Henry
# mdp.39015059959802         Morrison, Toni
# mdp.39015043798431         Morrison, Toni
# coo.31924052984741           James, Henry
# uc2.ark+=13960=fk8pc2tq9r    James, Henry
#
#                                                           shorttitle  \
# docid
# pst.000029895397           The turn of the screw : and other stories
# mdp.39015059959802                                              Love
# mdp.39015043798431                                              Sula
# coo.31924052984741                                   The ambassadors
# uc2.ark+=13960=fk8pc2tq9r                      The wings of the dove
#
#                            inferreddate  latestcomp  allcopiesofwork  \
# docid
# pst.000029895397                   1969        1916                1
# mdp.39015059959802                 2003        2003                1
# mdp.39015043798431                 1973        1973                4
# coo.31924052984741                 1903        1903               17
# uc2.ark+=13960=fk8pc2tq9r          1902        1902               23
#
#                            copiesin25yrs earlyedition  \
# docid
# pst.000029895397                       1        False
# mdp.39015059959802                     1         True
# mdp.39015043798431                     3         True
# coo.31924052984741                     5         True
# uc2.ark+=13960=fk8pc2tq9r             16         True
#
#                                                                      imprint  \
# docid
# pst.000029895397                                 Harmondsworth|Penguin|1969.
# mdp.39015059959802         New York|Knopf|Distributed by Random House|c2003.
# mdp.39015043798431                                 New York, NY|Plume|c1973.
# coo.31924052984741               New York and London;Harper & brothers;1903.
# uc2.ark+=13960=fk8pc2tq9r        Westminster;A. Constable and co. ltd.;1902.
#
#                            gender  firstpub  nationality  lastname
# docid
# pst.000029895397              NaN       NaN          NaN     James
# mdp.39015059959802            NaN       NaN          NaN  Morrison
# mdp.39015043798431            NaN       NaN          NaN  Morrison
# coo.31924052984741            NaN       NaN          NaN     James
# uc2.ark+=13960=fk8pc2tq9r     NaN       NaN          NaN     James

# %%
for c in tfcols:
    if c == 'mostdiscussed':
        discussdf[c] = True
    else:
        discussdf[c] = False

# %%
discussdf = discussdf.rename(index = str, columns = {'shorttitle': 'title'})
discussdf.head()
# Out:
#                                    author  \
# docid
# pst.000029895397             James, Henry
# mdp.39015059959802         Morrison, Toni
# mdp.39015043798431         Morrison, Toni
# coo.31924052984741           James, Henry
# uc2.ark+=13960=fk8pc2tq9r    James, Henry
#
#                                                                title  \
# docid
# pst.000029895397           The turn of the screw : and other stories
# mdp.39015059959802                                              Love
# mdp.39015043798431                                              Sula
# coo.31924052984741                                   The ambassadors
# uc2.ark+=13960=fk8pc2tq9r                      The wings of the dove
#
#                            inferreddate  latestcomp  allcopiesofwork  \
# docid
# pst.000029895397                   1969        1916                1
# mdp.39015059959802                 2003        2003                1
# mdp.39015043798431                 1973        1973                4
# coo.31924052984741                 1903        1903               17
# uc2.ark+=13960=fk8pc2tq9r          1902        1902               23
#
#                            copiesin25yrs earlyedition  \
# docid
# pst.000029895397                       1        False
# mdp.39015059959802                     1         True
# mdp.39015043798431                     3         True
# coo.31924052984741                     5         True
# uc2.ark+=13960=fk8pc2tq9r             16         True
#
#                                                                      imprint  \
# docid
# pst.000029895397                                 Harmondsworth|Penguin|1969.
# mdp.39015059959802         New York|Knopf|Distributed by Random House|c2003.
# mdp.39015043798431                                 New York, NY|Plume|c1973.
# coo.31924052984741               New York and London;Harper & brothers;1903.
# uc2.ark+=13960=fk8pc2tq9r        Westminster;A. Constable and co. ltd.;1902.
#
#                            gender  firstpub  nationality  lastname norton  \
# docid
# pst.000029895397              NaN       NaN          NaN     James  False
# mdp.39015059959802            NaN       NaN          NaN  Morrison  False
# mdp.39015043798431            NaN       NaN          NaN  Morrison  False
# coo.31924052984741            NaN       NaN          NaN     James  False
# uc2.ark+=13960=fk8pc2tq9r     NaN       NaN          NaN     James  False
#
#                            heath nortonshort mostdiscussed preregistered  \
# docid
# pst.000029895397           False       False          True         False
# mdp.39015059959802         False       False          True         False
# mdp.39015043798431         False       False          True         False
# coo.31924052984741         False       False          True         False
# uc2.ark+=13960=fk8pc2tq9r  False       False          True         False
#
#                           reviewed contrast4reviewed bestseller
# docid
# pst.000029895397             False             False      False
# mdp.39015059959802           False             False      False
# mdp.39015043798431           False             False      False
# coo.31924052984741           False             False      False
# uc2.ark+=13960=fk8pc2tq9r    False             False      False

# %%
newdf = pd.read_csv('second_supplement.tsv', sep = '\t', index_col = 'docid')
print(newdf.shape)
unified = pd.concat([newdf, discussdf])
unified.shape
# Out:
# (2121, 20)
# (2136, 20)

# %%
unified.reset_index(inplace = True)
unified = unified[cols]
unified.to_csv('second_supplement_full.tsv', sep = '\t', index = False)

# %%
therandomsample = pd.read_csv('lastnamesample.tsv', sep = '\t')

# %%
overlap = set(unified.docid).intersection(set(therandomsample.docid))
print(len(overlap))
# Out:
# 554

# %%
toadd = set(unified.docid) - overlap
print(len(toadd))
# Out:
# 1582

# %% [markdown]
# ### Oops, some docids are in the wrong format, which has permitted duplicates to exist

# %%
unified.reset_index(inplace = True)
import SonicScrewdriver as utils

# %%
for idx in unified.index:
    docid = unified.loc[idx, 'docid']
    unified.loc[idx, 'docid'] = utils.clean_pairtree(docid)
overlap = set(unified.docid).intersection(set(therandomsample.docid))
print(len(overlap))
# Out:
# 574

# %%
def get_record_id(idx):
    global master
    if idx not in master.index:
        return float('nan')
    else:
        return int(master.loc[idx, 'recordid'])

unified = unified.assign(recordid = unified.docid.map(get_record_id))
sum(pd.isnull(unified.recordid))
# Out:
# 58

# %%
toadd = set(unified.docid) - overlap
print(len(toadd))
# Out:
# 1544

# %%
randomblocked = therandomsample.assign(block = therandomsample.author.map(blockcode))

byblock = randomblocked.groupby('block')
block_dictionary = dict()

for code, df in byblock:
    block_dictionary[code] = df

# %%
unified.reset_index(inplace = True)

# %%
unified.columns
# Out:
# Index(['docid', 'author', 'title', 'inferreddate', 'latestcomp', 'firstpub',
#        'allcopiesofwork', 'copiesin25yrs', 'gender', 'nationality',
#        'earlyedition', 'lastname', 'imprint', 'norton', 'heath', 'nortonshort',
#        'mostdiscussed', 'preregistered', 'reviewed', 'contrast4reviewed',
#        'bestseller', 'recordid'],
#       dtype='object')

# %%
def collapse_duplicates(df):
    obligates = ['docid', 'author', 'title', 'inferreddate', 'latestcomp', 'firstpub',
       'allcopiesofwork', 'copiesin25yrs', 'gender', 'nationality',
       'earlyedition', 'lastname', 'imprint', 'recordid']
    r = dict()
    for o in obligates:
        if o == 'latestcomp':
            r[o] = min(df[o])
        elif o == 'gender' or o == 'nationality' or o == 'firstpub':
            for item in df[o]:
                if not pd.isnull(item):
                    r[o] = item
        else:
            r[o] = df[o].values[0]
    
    tfcols = ['norton', 'heath', 'nortonshort', 'mostdiscussed', 'preregistered', 
              'reviewed', 'contrast4reviewed', 'bestseller']
    
    for o in tfcols:
        if sum(df[o]) > 0:
            r[o] = True
        else:
            r[o] = False
    
    return r

# %%
from collections import Counter
doccounts = Counter(unified.docid)
todelete = []
fornewframe = []
ctr = 0
for k, v in doccounts.items():
    ctr += 1
    if ctr % 25 == 1:
        print(ctr)
        
    if v > 1:
        df = unified.loc[unified.docid == k, : ]
        r = collapse_duplicates(df)
        todelete.append(k)
        fornewframe.append(r)

newframe = pd.DataFrame(fornewframe)
print(newframe.shape)
newframe.head()
# Out:
# 1
# 26
# 51
# 76
# 101
# 126
# 151
# 176
# 201
# 226
# 251
# 276
# 301
# 326
# 351
# 376
# 401
# 426
# 451
# 476
# 501
# 526
# 551
# 576
# 601
# 626
# 651
# 676
# 701
# 726
# 751
# 776
# 801
# 826
# 851
# 876
# 901
# 926
# 951
# 976
# 1001
# 1026
# 1051
# 1076
# 1101
# 1126
# 1151
# 1176
# 1201
# 1226
# 1251
# 1276
# 1301
# 1326
# 1351
# 1376
# 1401
# 1426
# 1451
# 1476
# 1501
# 1526
# 1551
# 1576
# 1601
# 1626
# 1651
# 1676
# 1701
# 1726
# 1751
# 1776
# 1801
# 1826
# 1851
# 1876
# 1901
# 1926
# 1951
# 1976
# 2001
# 2026
# 2051
# 2076
# 2101
# (18, 22)
#    allcopiesofwork                       author bestseller contrast4reviewed  \
# 0              NaN                Larsen, Nella      False             False
# 1              2.0       Rinehart, Mary Roberts       True             False
# 2              NaN  Rice, Alice Caldwell Hegan,       True             False
# 3              3.0      McCutcheon, George Barr       True             False
# 4              1.0          Vance, Louis Joseph       True             False
#
#    copiesin25yrs                     docid earlyedition  firstpub gender  \
# 0            NaN     miun.aat2524,0001,001          NaN    1929.0      m
# 1            2.0  uc2.ark+=13960=t2g737p22         True    1910.0    NaN
# 2            NaN  uc2.ark+=13960=t4sj1bv84          NaN    1903.0    NaN
# 3            3.0  uc2.ark+=13960=t7br8n136         True    1904.0    NaN
# 4            1.0  uc2.ark+=13960=t9q23sh58         True    1907.0    NaN
#
#    heath             ...                 lastname  latestcomp mostdiscussed  \
# 0   True             ...                   Larsen      1929.0         False
# 1  False             ...                 Rinehart      1910.0         False
# 2  False             ...                     Rice      1903.0         False
# 3  False             ...               McCutcheon      1904.0         False
# 4  False             ...                    Vance      1907.0         False
#
#    nationality norton nortonshort preregistered   recordid reviewed  \
# 0           us  False       False         False        NaN     True
# 1          NaN  False       False         False  7671087.0    False
# 2          NaN  False       False         False  6498811.0    False
# 3          NaN  False       False         False  7645990.0    False
# 4          NaN  False       False         False  6541658.0    False
#
#                          title
# 0                      Passing
# 1  The window at the White Cat
# 2                   Lovey Mary
# 3         Beverly of Graustark
# 4               The brass bowl
#
# [5 rows x 22 columns]

# %%
print(unified.shape)
newunified = unified[~unified.docid.isin(todelete)]
newunified.shape
# Out:
# (2136, 22)
# (2100, 22)

# %%
unified = pd.concat([newunified, newframe])
unified.shape
# Out:
# (2118, 22)

# %% [markdown]
# Got rid of 18 duplicates.
#
# ### Now for the problem that some of our volumes are included as titles in the random sample, although not exactly the same docid

# %%
unified.reset_index(inplace = True)

# %%
for idx in unified.index:
    docid = unified.loc[idx, 'docid']
    unified.loc[idx, 'docid'] = utils.clean_pairtree(docid)
overlap = set(unified.docid).intersection(set(therandomsample.docid))
print(len(overlap))
# Out:
# 574

# %%
toadd = set(unified.docid) - overlap
print(len(toadd))
# Out:
# 1544

# %%
unified.set_index('docid', inplace = True)

# %%
def trimatitle(title):
    if '|' in title:
        title = title.split('|')[0]
    if ';' in title:
        title = title.split(';')[0]
    if ':' in title:
        title = title.split(':')[0]
    
    if len(title) > 28:
        title = title[0:28]
    
    return title

ctr = 0
allmatches = []
pairings = []
alreadytaken = set()

for idx in toadd:
    if idx in alreadytaken:
        continue
    origauth = unified.loc[idx, 'author']  
    normname = origauth.lower()
    
    origtitle = unified.loc[idx, 'title']
    title = trimatitle(origtitle.lower())
    
    code = normname[0:2]
    
    possiblematches = []
    
    recordid = unified.loc[idx, 'recordid']
    if pd.isnull(recordid):
        toreplacedf = unified.loc[(unified.author == origauth) & (unified.title == origtitle), : ]
    else:
        toreplacedf = unified.loc[unified.recordid == recordid, : ]
    
    docstotake = toreplacedf.index.tolist()
        
    origvolcount = len(docstotake)
    
    if code in block_dictionary:
        block = block_dictionary[code]
        for idx2, row2 in block.iterrows():
            auth2match = row2['author'].lower()
            if '(' in auth2match:
                auth2match = auth2match.split('(')[0]
            authsimilarity = fuzzymatch(normname, auth2match)
            if authsimilarity < 0.74: 
                continue
            
            title2match = row2['shorttitle']
            if pd.isnull(title2match):
                title2match = 'x x x'
            else:
                title2match = trimatitle(title2match)
                
            titlesimilarity = fuzzymatch(title, title2match)
            if titlesimilarity > 0.74:
                possiblematches.append((authsimilarity * titlesimilarity, idx2))

    if len(possiblematches) > 0:
        possiblematches.sort()
        probability, matchidx = possiblematches[-1]
        newrecordid = block.loc[matchidx, 'recordid']
        replacementdf = block.loc[block.recordid == newrecordid, :]
        pairings.append((docstotake, replacementdf))
        for d in docstotake:
            alreadytaken.add(d)
        matchvolcount = len(replacementdf.author)
        
        print(normname, ' | ', title, block.loc[matchidx, 'author'], ' == ', block.loc[matchidx, 'shorttitle'], 
              origvolcount, ':', matchvolcount)
        allmatches.append((probability, matchidx, normname, title, 
                           block.loc[matchidx, 'author'], block.loc[matchidx, 'shorttitle']))
        ctr += 1
    else:
        continue
# Out:
# mathers, helen,  |  comin' thro' the rye Mathers, Helen  ==  Comin' thro' the rye. A novel 2 : 1
# yonge, charlotte m  |  beechcroft at rockstone Yonge, Charlotte M. (Charlotte Mary)  ==  Beechcroft at Rockstone 1 : 2
# kavanagh, julia  |  seven years, and other tales Kavanagh, Julia  ==  Seven years, and other tales 1 : 2
# chambers, robert w.  |  the common law Chambers, Robert W. (Robert William)  ==  The common law 1 : 1
# ward, mary augusta  |  eleanor Ward, Mary Augusta  ==  Eleanor 1 : 1
# smart, hawley  |  tie and trick Smart, Hawley  ==  Tie and trick 1 : 1
# mallock, w. h  |  the heart of life Mallock, W. H. (William Hurrell)  ==  The heart of life 2 : 1
# reid, mayne  |  andrew deverel Reid, Mayne  ==  Andrew Deverel; 1 : 2
# russell, william clark  |  marooned Russell, William Clark  ==  Marooned; a sea tale 3 : 1
# aïdé, hamilton  |  poet and peer Aïdé, Hamilton  ==  Poet and peer 3 : 1
# tarkington, booth,  |  the two vanrevels Tarkington, Booth  ==  The two Vanrevels 2 : 1
# warburton, eliot  |  reginald hastings Warburton, Eliot  ==  Reginald Hastings 1 : 3
# wells, h. g  |  men like gods Wells, H. G. (Herbert George)  ==  Men like gods; a novel 1 : 1
# lytton, edward bulwer lytton,  |  pelham, or, the adventures o Lytton, Edward Bulwer Lytton, Baron  ==  Pelham, or adventures of a gentleman 1 : 1
# churchill, winston, sir  |  the crossing Churchill, Winston, Sir  ==  The crossing 1 : 1
# welty, eudora  |  the wide net and other stori Welty, Eudora  ==  The wide net, and other stories 1 : 1
# norris, frank,  |  the pit Norris, Frank  ==  The pit : a story of Chicago 1 : 1
# churchill, winston,  |  a far country Churchill, Winston, Sir  ==  A far country 1 : 1
# craik, dinah maria mulock,  |  john halifax, gentleman Craik, Dinah Maria (Mulock), Mrs  ==  John Halifax, gentleman 1 : 1
# locke, william john,  |  the morals of marcus ordeyne Locke, William John  ==  The morals of Marcus Ordeyne; a novel 1 : 1
# holyoke, hetty  |  blanche and her friends Holyoke, Hetty  ==  Blanche and her friends 1 : 1
# byron, george gordon byron,  |  childe harold's pilgrimage Byron, George Gordon Byron  ==  Childe Harold's pilgrimage 1 : 1
# ford, paul leicester,  |  janice meredith Ford, Paul Leicester  ==  Janice Meredith : a story of the American revolution 1 : 1

# %%
ctr
# Out:
# 271

# %%
unified.reset_index(inplace = True)
newrows = []

for docstodel, replacementdf in pairings:
    frame2replace = unified.loc[unified.docid.isin(docstodel), : ]
    r = collapse_duplicates(frame2replace)
    lastcomplist = list(frame2replace.latestcomp.values)
    lastcomplist.extend(replacementdf.latestcomp.values)
    lastcomplist = [x for x in lastcomplist if not pd.isnull(x)]
    lastcomp = min(lastcomplist)
    r['latestcomp'] = lastcomp
    numrows = min(frame2replace.shape[0], replacementdf.shape[0])
    newdocids = replacementdf.docid.values
    for n in range(numrows):
        thisr = dict(r)
        thisr['docid'] = newdocids[n]
        newrows.append(thisr)
        
paired = pd.DataFrame(newrows)
paired.head()
# Out:
#    allcopiesofwork               author bestseller contrast4reviewed  \
# 0              NaN       Mathers, Helen       True              True
# 1              1.0   Yonge, Charlotte M      False              True
# 2              NaN      Kavanagh, Julia      False              True
# 3              1.0  Chambers, Robert W.       True             False
# 4              NaN   Ward, Mary Augusta      False             False
#
#    copiesin25yrs                      docid earlyedition  firstpub gender  \
# 0            NaN         nyp.33433034410732          NaN    1875.0      f
# 1            1.0  uiuo.ark+=13960=t52f8d47f         True    1889.0      f
# 2            NaN         njp.32101068971058          NaN    1860.0      f
# 3            1.0   uc2.ark+=13960=t3804zn8k         True    1911.0    NaN
# 4            NaN         coo.31924013567106          NaN    1900.0      f
#
#    heath              ...               lastname  latestcomp mostdiscussed  \
# 0  False              ...                Mathers      1875.0         False
# 1  False              ...                  Yonge      1888.0         False
# 2  False              ...               Kavanagh      1860.0         False
# 3  False              ...               Chambers      1911.0         False
# 4  False              ...                   Ward      1900.0         False
#
#    nationality norton nortonshort preregistered   recordid reviewed  \
# 0           uk  False       False         False  7690510.0    False
# 1           uk  False       False         False  9438764.0    False
# 2           ir  False       False         False  9014927.0    False
# 3          NaN  False       False         False   778808.0    False
# 4           uk  False       False         False   784781.0     True
#
#                           title
# 0          Comin' thro' the rye
# 1       Beechcroft at Rockstone
# 2  Seven years, and other tales
# 3                The Common law
# 4                      Eleanor;
#
# [5 rows x 22 columns]

# %%
paired.shape
# Out:
# (295, 22)

# %%
len(alreadytaken)
# Out:
# 358

# %%
print(unified.shape)
newunified = unified[~unified.docid.isin(alreadytaken)]
newunified.shape
# Out:
# (2118, 22)
# (1760, 22)

# %%
newunified = pd.concat([newunified, paired])
newunified.shape
# Out:
# (2055, 22)

# %%
overlap = set(newunified.docid).intersection(set(therandomsample.docid))
print(len(overlap))
# Out:
# 778

# %%
toadd = set(newunified.docid) - overlap
print(len(toadd))
# Out:
# 1247

# %%
newunified.to_csv('second_supplement_maxoverlap.tsv', sep = '\t', index = False)
